# %%
# this is demonstration for 3D from photo reconstruction
# https://github.com/3DTopia/OpenLRM

# %%
# !pip install opencv-python rembg gradio open3d matplotlib
# Out:
# WARNING: Ignoring invalid distribution - (/home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages)
# Requirement already satisfied: opencv-python in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (4.8.1.78)
# Requirement already satisfied: rembg in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (2.0.53)
# Requirement already satisfied: gradio in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (4.7.1)
# Requirement already satisfied: open3d in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: matplotlib in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: numpy>=1.21.2 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from opencv-python) (1.22.0)
# Requirement already satisfied: jsonschema in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (4.20.0)
# Requirement already satisfied: onnxruntime in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (1.16.3)
# Requirement already satisfied: opencv-python-headless in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (4.9.0.80)
# Requirement already satisfied: pillow in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (10.1.0)
# Requirement already satisfied: pooch in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (1.8.0)
# Requirement already satisfied: pymatting in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (1.1.12)
# Requirement already satisfied: scikit-image in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (0.22.0)
# Requirement already satisfied: scipy in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (1.11.4)
# Requirement already satisfied: tqdm in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rembg) (4.66.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (5.2.0)
# Requirement already satisfied: fastapi in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.105.0)
# Requirement already satisfied: ffmpy in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.7.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.7.0)
# Requirement already satisfied: httpx in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.26.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.16.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (3.9.10)
# Requirement already satisfied: packaging in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pydantic>=2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (2.5.3)
# Requirement already satisfied: pydub in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (2.31.0)
# Requirement already satisfied: semantic-version~=2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (4.9.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio) (0.25.0)
# Requirement already satisfied: fsspec in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio-client==0.7.0->gradio) (2023.12.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from gradio-client==0.7.0->gradio) (11.0.3)
# Requirement already satisfied: dash>=2.6.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from open3d) (2.14.2)
# Requirement already satisfied: werkzeug>=2.2.3 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from open3d) (3.0.1)
# Requirement already satisfied: nbformat==5.7.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from open3d) (5.7.0)
# Requirement already satisfied: configargparse in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from open3d) (1.7)
# Requirement already satisfied: ipywidgets>=8.0.4 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from open3d) (8.1.1)
# Requirement already satisfied: addict in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from open3d) (2.4.0)
# Requirement already satisfied: scikit-learn>=0.21 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from open3d) (1.3.2)
# Requirement already satisfied: pyquaternion in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from open3d) (0.9.9)
# Requirement already satisfied: fastjsonschema in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from nbformat==5.7.0->open3d) (2.19.0)
# Requirement already satisfied: jupyter-core in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from nbformat==5.7.0->open3d) (5.5.1)
# Requirement already satisfied: traitlets>=5.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from nbformat==5.7.0->open3d) (5.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: toolz in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (3.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (5.18.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (5.0.0)
# Requirement already satisfied: retrying in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (1.3.4)
# Requirement already satisfied: ansi2html in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (1.9.1)
# Requirement already satisfied: nest-asyncio in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (1.5.8)
# Requirement already satisfied: setuptools in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (68.2.2)
# Requirement already satisfied: importlib-metadata in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (7.0.0)
# Requirement already satisfied: filelock in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio) (3.13.1)
# Requirement already satisfied: comm>=0.1.3 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (8.18.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (3.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from jsonschema->rembg) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from jsonschema->rembg) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from jsonschema->rembg) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from jsonschema->rembg) (0.15.2)
# Requirement already satisfied: pytz>=2020.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (2.14.6)
# Requirement already satisfied: six>=1.5 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from requests~=2.0->gradio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from requests~=2.0->gradio) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from requests~=2.0->gradio) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from requests~=2.0->gradio) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d) (3.2.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (13.7.0)
# Requirement already satisfied: h11>=0.8 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: httpcore==1.* in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from httpx->gradio) (1.0.2)
# Requirement already satisfied: sniffio in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: coloredlogs in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from onnxruntime->rembg) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from onnxruntime->rembg) (23.5.26)
# Requirement already satisfied: protobuf in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from onnxruntime->rembg) (3.20.3)
# Requirement already satisfied: sympy in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from onnxruntime->rembg) (1.12)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from pooch->rembg) (4.1.0)
# Requirement already satisfied: numba!=0.49.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from pymatting->rembg) (0.58.1)
# Requirement already satisfied: networkx>=2.8 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from scikit-image->rembg) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from scikit-image->rembg) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from scikit-image->rembg) (2023.12.9)
# Requirement already satisfied: lazy_loader>=0.3 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from scikit-image->rembg) (0.3)
# Requirement already satisfied: exceptiongroup in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.2.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (1.6.2)
# Requirement already satisfied: decorator in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.17.2)
# Requirement already satisfied: stack-data in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.9.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from numba!=0.49.0->pymatting->rembg) (0.41.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (8.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from coloredlogs->onnxruntime->rembg) (10.0)
# Requirement already satisfied: zipp>=0.5 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.17.0)
# Requirement already satisfied: mpmath>=0.19 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from sympy->onnxruntime->rembg) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.0)
# Requirement already satisfied: wcwidth in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.4.1)
# Requirement already satisfied: pure-eval in /home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.2)
# WARNING: Ignoring invalid distribution - (/home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/zipa/anaconda3/envs/py10/lib/python3.10/site-packages)

# %%
# import libraries to preprocess image
from matplotlib import pyplot as plt
# %matplotlib inline

import cv2
import numpy as np
import os.path
from PIL import Image
from rembg import remove

# this function crops source image to fit in 512x512 square window
def crop_512(img):
    img, alpha = img[:,:,:3], img[:,:,3]
    img.reshape(-1, 3)[alpha.reshape(-1)==0] = [255, 255, 255]
    x, y, w, h = cv2.boundingRect(alpha)
    img = img[y:y+h, x:x+w, :]

    if max(h, w) > 512:
        scale_factor = 412.0 / max(h, w)
        new_w, new_h = int(scale_factor * w), int(scale_factor * h)
        img = cv2.resize(img, (new_w, new_h))
        h, w = img.shape[:2]

    assert(max(h, w) <= 512)
    dh, dw = (512 - h) // 2, (512 - w) // 2
    img = np.pad(img, [(dh, 512 - dh - h), (dw, 512 - dw - w), (0, 0)], constant_values=255)

    # print(img.shape)
    # plt.imshow(img)
    # plt.show()
    assert (img.shape[0] == 512)
    assert (img.shape[1] == 512)
    return img

# this function removes background
def get_object(src_path: str, erosion_coeff=1.5) -> np.ndarray:
    if not os.path.exists(src_path):
        print(f"No such file or directory: {src_path}")
        return None
    with Image.open(src_path) as test:
        res = remove(test, False)
        res = np.asarray(res).copy()
        if erosion_coeff > 0:
            pix_size = int(erosion_coeff * max(res.shape[0], res.shape[1]) / 224)
            res[:,:,3] = cv2.erode(res[:,:,3], np.ones((2*pix_size+1, 2*pix_size+1)))
        return res

# this function loads and preprocess image to be used in reconstruction
def load_preprocessed(path):
    test = get_object(path)
    if test is not None:
        test = crop_512(test)
    return test

# %%
test = get_object("./assets/with_background/bear.JPG")#"/home/zipa/Pictures/Leonardo_Diffusion_XL_Year_of_a_green_wooden_dragon_1.webp" )
if test is not None:
    test = crop_512(test)
    plt.imshow(test)
    plt.show()

# %%
# !cd lrm

# %%
# !ls
# Out:
# app.py	demo.ipynb  LICENSE_NVIDIA  lrm		   README.md
# assets	LICENSE     LICENSE_WEIGHT  model_card.md  requirements.txt

# %%
# now we perform the reconstruction (code derived and reformed from lrm.inferrer)
import torch
from lrm.inferrer import LRMInferrer


def prepare_numpy(source_image: np.ndarray, source_image_size):
    image = torch.tensor(source_image).permute(2, 0, 1).unsqueeze(0) / 255.0
    # if RGBA, blend to RGB
    if image.shape[1] == 4:
        image = image[:, :3, ...] * image[:, 3:, ...] + (1 - image[:, 3:, ...])
    image = torch.nn.functional.interpolate(image, size=(source_image_size, source_image_size), mode='bicubic', align_corners=True)
    image = torch.clamp(image, 0, 1)
    return image

# this function repeats LRMInferrer.infer
# but we load and unload data from\to memory, not on disk
def demo_infer(obj: LRMInferrer, source_image: np.ndarray, source_size: int, render_size: int, mesh_size: int):
    if source_size <= 0:
        source_size = obj.infer_kwargs['source_size']
    if render_size <= 0:
        render_size = obj.infer_kwargs['render_size']
    
    image = prepare_numpy(source_image, source_size)
    return obj.infer_single(
        image.to(obj.device),
        render_size=render_size,
        mesh_size=mesh_size,
        export_video=True,
        export_mesh=True,
    )
    
with LRMInferrer(model_name='lrm-base-obj-v1') as inferrer:
    results = demo_infer(inferrer,
        source_image=test,
        source_size=-1,
        render_size=-1,
        mesh_size=384
    )
# results = {'frames': {'images_rgb': ..., 'images_depth'..., 'images_weight'...}, 'mesh': []}
# Out:
# ======== Loaded model from checkpoint ========

# %%
images = results['frames']['images_rgb'][0]
depths = results['frames']['images_depth'][0]
weights = results['frames']['images_weight'][0]

# %%
# function to plot different frames as a grid
def plot_grid(arr, indices):
    grid_size = int(np.ceil(np.sqrt(len(indices))))
    fig, axes = plt.subplots(grid_size, grid_size)
    for i, axe in enumerate(axes.flatten()):
        axe.axis('off')
        if i < len(indices) and indices[i] < len(arr):
            elem = arr[indices[i]]
            if isinstance(elem, torch.Tensor):
                elem = elem.cpu().detach().permute(1, 2, 0).numpy()
            axe.imshow(elem)
            axe.set_title(indices[i])

# %%
# визуализируем 4 кадра из последовательности визуализации
# можно заменить в этой ячейке images на depths и weights
plot_grid(images, range(0, 160, 40))

# %%
inferrer.images_to_video(images, "./result.mov", fps=40)
_ = results["mesh"].export('result.ply', 'ply') # return _ to omit output from printing
# Out:
# [mpeg4 @ 0x6f34b00] too many threads/slices (13), reducing to 12

# %%
import open3d as o3d
# print(o3d.__version__)
mesh = o3d.io.read_point_cloud('result.ply')
o3d.visualization.draw_geometries([mesh])
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
_ = results["mesh"].export('result.gltf', 'gltf') #

# %%
# mesh = o3d.io.read_point_cloud('result.gltf')
# o3d.visualization.draw_geometries([mesh])
# Out:
# [Open3D WARNING] Read geometry::PointCloud failed: unknown file extension for result.gltf (format: auto).
